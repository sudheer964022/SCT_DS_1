# %%
pip install pandas matplotlib

# %%
import pandas as pd

# %% [markdown]
# **Load and Inspect the Data**

# %%
# Load the data from the uploaded files
population_data = pd.read_csv('/content/world_bank_data/API_SP.POP.TOTL_DS2_en_csv_v2_2001050.csv', skiprows=4)

# %%
metadata_country = pd.read_csv('/content/world_bank_data/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_2001050.csv')

# %%
metadata_indicator = pd.read_csv('/content/world_bank_data/Metadata_Indicator_API_SP.POP.TOTL_DS2_en_csv_v2_2001050.csv')

# %%
# Inspect the first few rows of each DataFrame
print(population_data.head())
print(metadata_country.head())
print(metadata_indicator.head())
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %% [markdown]
# **Filter and Process Data for India**

# %%
# Filter the data for India
india_population_data = population_data[population_data['Country Name'] == 'India']

# %%
# Extract relevant columns (year 2022)
population_2022 = india_population_data[['Country Name', '2022']]

# %%
# Print the population of India in 2022
print(f"Population of India in 2022: {population_2022.iloc[0]['2022']}")
# Out:
# Population of India in 2022: 1417173173.0

# %% [markdown]
# **Create a Bar Chart**

# %%
import matplotlib.pyplot as plt

# %%
data = {
    'Age Group': ['0-20', '21-64', '65+'],
    'Population (Millions)': [512, 807, 98]
}

# %%
# Create a DataFrame
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Age Group'], df['Population (Millions)'], color=['yellow', 'blue', 'pink'])

# Adding titles and labels
plt.title("India's Population Distribution by Age in 2022")
plt.xlabel('Age Group')
plt.ylabel('Population (Millions)')

# Show plot
plt.show()
